# %%
###Solution to question no. 1###

# %%
import numpy as np
np.random.seed(100)
arr= np.random.randint(1,11, size=(6,10))
out_put= np.zeros((6,10), dtype=int)

# %%
arr
# Out:
# array([[ 9,  9,  4,  8,  8,  1,  5,  3,  6,  3],
#        [ 3,  3,  2,  1,  9,  5,  1, 10,  7,  3],
#        [ 5,  2,  6,  4,  5,  5,  4,  8,  2,  2],
#        [ 8,  8,  1,  3, 10, 10,  4,  3,  6,  9],
#        [ 2,  1,  8,  7,  3,  1,  9,  3,  6,  2],
#        [ 9,  2,  6,  5,  3,  9,  4,  6,  1, 10]])

# %%
for row in range(len(arr)):
    x,y =np.unique(arr[row], return_counts=True) # x= elements, y = frequency count
    out_put[row,x-1] =y # assign vlaues to each columns
    
out_put
# Out:
# array([[1, 0, 2, 1, 1, 1, 0, 2, 2, 0],
#        [2, 1, 3, 0, 1, 0, 1, 0, 1, 1],
#        [0, 3, 0, 2, 3, 1, 0, 1, 0, 0],
#        [1, 0, 2, 1, 0, 1, 0, 2, 1, 2],
#        [2, 2, 2, 0, 0, 1, 1, 1, 1, 0],
#        [1, 1, 1, 1, 1, 2, 0, 0, 2, 1]])

# %%
###Solution to question no. 2###

# %%
import pandas as pd
df =pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/Cars93_miss.csv', usecols=[0,1,2,3,5])

# %%
df
# Out:
#    Manufacturer          Model     Type  Min.Price  Max.Price
# 0         Acura        Integra    Small       12.9       18.8
# 1           NaN         Legend  Midsize       29.2       38.7
# 2          Audi             90  Compact       25.9       32.3
# 3          Audi            100  Midsize        NaN       44.6
# 4           BMW           535i  Midsize        NaN        NaN
# 5         Buick        Century  Midsize       14.2       17.3
# 6         Buick        LeSabre    Large       19.9        NaN
# 7         Buick     Roadmaster    Large       22.6       24.9
# 8         Buick        Riviera  Midsize       26.3       26.3
# 9      Cadillac        DeVille    Large       33.0       36.3
# 10     Cadillac        Seville  Midsize       37.5       42.7
# 11    Chevrolet       Cavalier  Compact        8.5       18.3
# 12    Chevrolet        Corsica  Compact       11.4       11.4
# 13    Chevrolet         Camaro   Sporty       13.4       16.8
# 14    Chevrolet         Lumina  Midsize       13.4       18.4
# 15    Chevrolet     Lumina_APV      Van       14.7       18.0
# 16    Chevrolet          Astro      Van       14.7       18.6
# 17    Chevrolet        Caprice    Large       18.0       19.6
# 18    Chevrolet       Corvette   Sporty       34.6       41.5
# 19          NaN       Concorde    Large       18.4       18.4
# 20     Chrysler        LeBaron  Compact       14.5       17.1
# 21     Chrysler       Imperial    Large       29.5       29.5
# 22        Dodge           Colt    Small        7.9       10.6
# 23        Dodge         Shadow    Small        8.4       14.2
# 24        Dodge         Spirit  Compact       11.9       14.7
# 25        Dodge        Caravan      Van        NaN       24.4
# 26        Dodge        Dynasty  Midsize       14.8       16.4
# 27        Dodge        Stealth   Sporty       18.5       33.1
# 28        Eagle         Summit    Small        7.9       16.5
# 29        Eagle         Vision    Large        NaN       21.2
# ..          ...            ...      ...        ...        ...
# 63       Nissan         Sentra    Small        8.7       14.9
# 64       Nissan         Altima  Compact       13.0       18.3
# 65       Nissan          Quest      Van       16.7       21.5
# 66       Nissan         Maxima  Midsize       21.0       22.0
# 67   Oldsmobile        Achieva  Compact       13.0       14.0
# 68   Oldsmobile  Cutlass_Ciera  Midsize       14.2       18.4
# 69   Oldsmobile     Silhouette      Van       19.5       19.5
# 70   Oldsmobile   Eighty-Eight    Large       19.5       21.9
# 71     Plymouth          Laser   Sporty       11.4       17.4
# 72      Pontiac         LeMans    Small        NaN        9.9
# 73      Pontiac        Sunbird  Compact        9.4       12.8
# 74      Pontiac       Firebird      NaN       14.0       21.4
# 75      Pontiac     Grand_Prix  Midsize       15.4       21.6
# 76      Pontiac     Bonneville    Large       19.4       29.4
# 77         Saab            900  Compact       20.3       37.1
# 78       Saturn             SL    Small        9.2       12.9
# 79       Subaru          Justy    Small        7.3        9.5
# 80       Subaru         Loyale    Small       10.5       11.3
# 81       Subaru         Legacy  Compact       16.3       22.7
# 82       Suzuki          Swift      NaN        7.3        NaN
# 83       Toyota         Tercel    Small        NaN       11.8
# 84       Toyota         Celica   Sporty       14.2       22.6
# 85       Toyota          Camry  Midsize       15.2       21.2
# 86       Toyota         Previa      Van        NaN       26.6
# 87   Volkswagen            Fox    Small        8.7        9.5
# 88   Volkswagen        Eurovan      Van       16.6       22.7
# 89   Volkswagen         Passat  Compact       17.6       22.4
# 90   Volkswagen        Corrado   Sporty       22.9       23.7
# 91        Volvo            240  Compact       21.8       23.5
# 92          NaN            850  Midsize       24.8       28.5
#
# [93 rows x 5 columns]

# %%
cols = ['Manufacturer','Type','Model']
df[cols]=df[cols].fillna('missing')
###Combining the three columns as index
df.index=df['Manufacturer'] +' '+df['Type']+' '+df['Model']
df
# Out:
#                                  Manufacturer          Model     Type  \
# Acura Small Integra                     Acura        Integra    Small
# missing Midsize Legend                missing         Legend  Midsize
# Audi Compact 90                          Audi             90  Compact
# Audi Midsize 100                         Audi            100  Midsize
# BMW Midsize 535i                          BMW           535i  Midsize
# Buick Midsize Century                   Buick        Century  Midsize
# Buick Large LeSabre                     Buick        LeSabre    Large
# Buick Large Roadmaster                  Buick     Roadmaster    Large
# Buick Midsize Riviera                   Buick        Riviera  Midsize
# Cadillac Large DeVille               Cadillac        DeVille    Large
# Cadillac Midsize Seville             Cadillac        Seville  Midsize
# Chevrolet Compact Cavalier          Chevrolet       Cavalier  Compact
# Chevrolet Compact Corsica           Chevrolet        Corsica  Compact
# Chevrolet Sporty Camaro             Chevrolet         Camaro   Sporty
# Chevrolet Midsize Lumina            Chevrolet         Lumina  Midsize
# Chevrolet Van Lumina_APV            Chevrolet     Lumina_APV      Van
# Chevrolet Van Astro                 Chevrolet          Astro      Van
# Chevrolet Large Caprice             Chevrolet        Caprice    Large
# Chevrolet Sporty Corvette           Chevrolet       Corvette   Sporty
# missing Large Concorde                missing       Concorde    Large
# Chrysler Compact LeBaron             Chrysler        LeBaron  Compact
# Chrysler Large Imperial              Chrysler       Imperial    Large
# Dodge Small Colt                        Dodge           Colt    Small
# Dodge Small Shadow                      Dodge         Shadow    Small
# Dodge Compact Spirit                    Dodge         Spirit  Compact
# Dodge Van Caravan                       Dodge        Caravan      Van
# Dodge Midsize Dynasty                   Dodge        Dynasty  Midsize
# Dodge Sporty Stealth                    Dodge        Stealth   Sporty
# Eagle Small Summit                      Eagle         Summit    Small
# Eagle Large Vision                      Eagle         Vision    Large
# ...                                       ...            ...      ...
# Nissan Small Sentra                    Nissan         Sentra    Small
# Nissan Compact Altima                  Nissan         Altima  Compact
# Nissan Van Quest                       Nissan          Quest      Van
# Nissan Midsize Maxima                  Nissan         Maxima  Midsize
# Oldsmobile Compact Achieva         Oldsmobile        Achieva  Compact
# Oldsmobile Midsize Cutlass_Ciera   Oldsmobile  Cutlass_Ciera  Midsize
# Oldsmobile Van Silhouette          Oldsmobile     Silhouette      Van
# Oldsmobile Large Eighty-Eight      Oldsmobile   Eighty-Eight    Large
# Plymouth Sporty Laser                Plymouth          Laser   Sporty
# Pontiac Small LeMans                  Pontiac         LeMans    Small
# Pontiac Compact Sunbird               Pontiac        Sunbird  Compact
# Pontiac missing Firebird              Pontiac       Firebird  missing
# Pontiac Midsize Grand_Prix            Pontiac     Grand_Prix  Midsize
# Pontiac Large Bonneville              Pontiac     Bonneville    Large
# Saab Compact 900                         Saab            900  Compact
# Saturn Small SL                        Saturn             SL    Small
# Subaru Small Justy                     Subaru          Justy    Small
# Subaru Small Loyale                    Subaru         Loyale    Small
# Subaru Compact Legacy                  Subaru         Legacy  Compact
# Suzuki missing Swift                   Suzuki          Swift  missing
# Toyota Small Tercel                    Toyota         Tercel    Small
# Toyota Sporty Celica                   Toyota         Celica   Sporty
# Toyota Midsize Camry                   Toyota          Camry  Midsize
# Toyota Van Previa                      Toyota         Previa      Van
# Volkswagen Small Fox               Volkswagen            Fox    Small
# Volkswagen Van Eurovan             Volkswagen        Eurovan      Van
# Volkswagen Compact Passat          Volkswagen         Passat  Compact
# Volkswagen Sporty Corrado          Volkswagen        Corrado   Sporty
# Volvo Compact 240                       Volvo            240  Compact
# missing Midsize 850                   missing            850  Midsize
#
#                                   Min.Price  Max.Price
# Acura Small Integra                    12.9       18.8
# missing Midsize Legend                 29.2       38.7
# Audi Compact 90                        25.9       32.3
# Audi Midsize 100                        NaN       44.6
# BMW Midsize 535i                        NaN        NaN
# Buick Midsize Century                  14.2       17.3
# Buick Large LeSabre                    19.9        NaN
# Buick Large Roadmaster                 22.6       24.9
# Buick Midsize Riviera                  26.3       26.3
# Cadillac Large DeVille                 33.0       36.3
# Cadillac Midsize Seville               37.5       42.7
# Chevrolet Compact Cavalier              8.5       18.3
# Chevrolet Compact Corsica              11.4       11.4
# Chevrolet Sporty Camaro                13.4       16.8
# Chevrolet Midsize Lumina               13.4       18.4
# Chevrolet Van Lumina_APV               14.7       18.0
# Chevrolet Van Astro                    14.7       18.6
# Chevrolet Large Caprice                18.0       19.6
# Chevrolet Sporty Corvette              34.6       41.5
# missing Large Concorde                 18.4       18.4
# Chrysler Compact LeBaron               14.5       17.1
# Chrysler Large Imperial                29.5       29.5
# Dodge Small Colt                        7.9       10.6
# Dodge Small Shadow                      8.4       14.2
# Dodge Compact Spirit                   11.9       14.7
# Dodge Van Caravan                       NaN       24.4
# Dodge Midsize Dynasty                  14.8       16.4
# Dodge Sporty Stealth                   18.5       33.1
# Eagle Small Summit                      7.9       16.5
# Eagle Large Vision                      NaN       21.2
# ...                                     ...        ...
# Nissan Small Sentra                     8.7       14.9
# Nissan Compact Altima                  13.0       18.3
# Nissan Van Quest                       16.7       21.5
# Nissan Midsize Maxima                  21.0       22.0
# Oldsmobile Compact Achieva             13.0       14.0
# Oldsmobile Midsize Cutlass_Ciera       14.2       18.4
# Oldsmobile Van Silhouette              19.5       19.5
# Oldsmobile Large Eighty-Eight          19.5       21.9
# Plymouth Sporty Laser                  11.4       17.4
# Pontiac Small LeMans                    NaN        9.9
# Pontiac Compact Sunbird                 9.4       12.8
# Pontiac missing Firebird               14.0       21.4
# Pontiac Midsize Grand_Prix             15.4       21.6
# Pontiac Large Bonneville               19.4       29.4
# Saab Compact 900                       20.3       37.1
# Saturn Small SL                         9.2       12.9
# Subaru Small Justy                      7.3        9.5
# Subaru Small Loyale                    10.5       11.3
# Subaru Compact Legacy                  16.3       22.7
# Suzuki missing Swift                    7.3        NaN
# Toyota Small Tercel                     NaN       11.8
# Toyota Sporty Celica                   14.2       22.6
# Toyota Midsize Camry                   15.2       21.2
# Toyota Van Previa                       NaN       26.6
# Volkswagen Small Fox                    8.7        9.5
# Volkswagen Van Eurovan                 16.6       22.7
# Volkswagen Compact Passat              17.6       22.4
# Volkswagen Sporty Corrado              22.9       23.7
# Volvo Compact 240                      21.8       23.5
# missing Midsize 850                    24.8       28.5
#
# [93 rows x 5 columns]

# %%
df.keys()
# Out:
# Index(['Manufacturer', 'Model', 'Type', 'Min.Price', 'Max.Price'], dtype='object')

# %%
if len(df.index) == df.index.nunique():
    print('The index is a primary key')

else:
    print('Not Primary')
# Out:
# The index is a primary key

# %% [markdown]
# Since all the index are unique, so we conclude that the combination of the three columns is a primary key
