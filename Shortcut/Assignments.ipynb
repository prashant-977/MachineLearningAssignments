# %%
###Solution to question no. 1###

# %%
import numpy as np
np.random.seed(100)
arr= np.random.randint(1,11, size=(6,10))
out_put= np.zeros((6,10), dtype=int)

# %%
arr
# Out:
# array([[ 9,  9,  4,  8,  8,  1,  5,  3,  6,  3],
#        [ 3,  3,  2,  1,  9,  5,  1, 10,  7,  3],
#        [ 5,  2,  6,  4,  5,  5,  4,  8,  2,  2],
#        [ 8,  8,  1,  3, 10, 10,  4,  3,  6,  9],
#        [ 2,  1,  8,  7,  3,  1,  9,  3,  6,  2],
#        [ 9,  2,  6,  5,  3,  9,  4,  6,  1, 10]])

# %%
for row in range(len(arr)):
    x,y =np.unique(arr[row], return_counts=True) # x= elements, y = frequency count
    out_put[row,x-1] =y # assign vlaues to each columns
    
out_put
# Out:
# array([[1, 0, 2, 1, 1, 1, 0, 2, 2, 0],
#        [2, 1, 3, 0, 1, 0, 1, 0, 1, 1],
#        [0, 3, 0, 2, 3, 1, 0, 1, 0, 0],
#        [1, 0, 2, 1, 0, 1, 0, 2, 1, 2],
#        [2, 2, 2, 0, 0, 1, 1, 1, 1, 0],
#        [1, 1, 1, 1, 1, 2, 0, 0, 2, 1]])

# %%
###Solution to question no. 2###

# %%
import pandas as pd
df =pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/Cars93_miss.csv', usecols=[0,1,2,3,5])

# %%
df
# Out:
#    Manufacturer          Model     Type  Min.Price  Max.Price
# 0         Acura        Integra    Small       12.9       18.8
# 1           NaN         Legend  Midsize       29.2       38.7
# 2          Audi             90  Compact       25.9       32.3
# 3          Audi            100  Midsize        NaN       44.6
# 4           BMW           535i  Midsize        NaN        NaN
# 5         Buick        Century  Midsize       14.2       17.3
# 6         Buick        LeSabre    Large       19.9        NaN
# 7         Buick     Roadmaster    Large       22.6       24.9
# 8         Buick        Riviera  Midsize       26.3       26.3
# 9      Cadillac        DeVille    Large       33.0       36.3
# 10     Cadillac        Seville  Midsize       37.5       42.7
# 11    Chevrolet       Cavalier  Compact        8.5       18.3
# 12    Chevrolet        Corsica  Compact       11.4       11.4
# 13    Chevrolet         Camaro   Sporty       13.4       16.8
# ...

# %%
cols = ['Manufacturer','Model','Type']
df[cols]=df[cols].fillna('missing')
###Combining the three columns as index


#df.index=df['Manufacturer'] +'_'+df['Type']+'_'+df['Model']

'''
Or, simply, we can use apply method of pandas
'''
df.index=df[cols].apply(lambda y : '_'.join(y), axis = 1)
df
# Out:
#                                  Manufacturer          Model     Type  \
# Acura_Integra_Small                     Acura        Integra    Small
# missing_Legend_Midsize                missing         Legend  Midsize
# Audi_90_Compact                          Audi             90  Compact
# Audi_100_Midsize                         Audi            100  Midsize
# BMW_535i_Midsize                          BMW           535i  Midsize
# Buick_Century_Midsize                   Buick        Century  Midsize
# Buick_LeSabre_Large                     Buick        LeSabre    Large
# Buick_Roadmaster_Large                  Buick     Roadmaster    Large
# Buick_Riviera_Midsize                   Buick        Riviera  Midsize
# Cadillac_DeVille_Large               Cadillac        DeVille    Large
# Cadillac_Seville_Midsize             Cadillac        Seville  Midsize
# Chevrolet_Cavalier_Compact          Chevrolet       Cavalier  Compact
# ...

# %%
df.index
# Out:
# Index(['Acura_Integra_Small', 'missing_Legend_Midsize', 'Audi_90_Compact',
#        'Audi_100_Midsize', 'BMW_535i_Midsize', 'Buick_Century_Midsize',
#        'Buick_LeSabre_Large', 'Buick_Roadmaster_Large',
#        'Buick_Riviera_Midsize', 'Cadillac_DeVille_Large',
#        'Cadillac_Seville_Midsize', 'Chevrolet_Cavalier_Compact',
#        'Chevrolet_Corsica_Compact', 'Chevrolet_Camaro_Sporty',
#        'Chevrolet_Lumina_Midsize', 'Chevrolet_Lumina_APV_Van',
#        'Chevrolet_Astro_Van', 'Chevrolet_Caprice_Large',
#        'Chevrolet_Corvette_Sporty', 'missing_Concorde_Large',
#        'Chrysler_LeBaron_Compact', 'Chrysler_Imperial_Large',
#        'Dodge_Colt_Small', 'Dodge_Shadow_Small', 'Dodge_Spirit_Compact',
#        'Dodge_Caravan_Van', 'Dodge_Dynasty_Midsize', 'Dodge_Stealth_Sporty',
#        'Eagle_Summit_Small', 'Eagle_Vision_Large', 'Ford_Festiva_Small',
#        'Ford_Escort_Small', 'Ford_Tempo_Compact', 'Ford_Mustang_Sporty',
# ...

# %%
if len(df.index) == df.index.nunique():
    print('The index is a primary key')

else:
    print('Not Primary')
# Out:
# The index is a primary key

# %% [markdown]
# Since all the index are unique, so we conclude that the combination of the three columns is a primary key
